# %%
# !pip3 install -U scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np 
import pandas as pd

# %%
peptide=pd.read_excel('Research.xlsx')
peptide
# Out:
#                       Compounds  Molecular Weight  Fraction sp3  Heavy Atom  \
# 0              Proline-Tyrosine              2.78          0.43        20.0
# 1            Proline-Tryptophan              3.01          0.38        22.0
# 2         Proline-Phenylalanine              2.62          0.43        19.0
# 3               Proline-Alanine              1.86          0.75        13.0
# 4               Proline-Glycine              1.72          0.71        12.0
# 5                Proline-Valine              2.14          0.80        15.0
# 6              Proline-Cysteine              2.18          0.75        14.0
# 7            Proline-Methionine              2.46          0.80        16.0
# 8               Proline-Leucine              2.28          0.82        16.0
# 9             Proline-Threonine              2.16          0.78        15.0
# 10               Proline-Serine              2.02          0.75        14.0
# ...

# %%
peptide.head(10)
# Out:
#                Compounds  Molecular Weight  Fraction sp3  Heavy Atom  \
# 0       Proline-Tyrosine              2.78          0.43        20.0
# 1     Proline-Tryptophan              3.01          0.38        22.0
# 2  Proline-Phenylalanine              2.62          0.43        19.0
# 3        Proline-Alanine              1.86          0.75        13.0
# 4        Proline-Glycine              1.72          0.71        12.0
# 5         Proline-Valine              2.14          0.80        15.0
# 6       Proline-Cysteine              2.18          0.75        14.0
# 7     Proline-Methionine              2.46          0.80        16.0
# 8        Proline-Leucine              2.28          0.82        16.0
# 9      Proline-Threonine              2.16          0.78        15.0
#
#    Aromatic Heavy Atom  Rotable Bond  Hydrogen Bond Donor  H-Bond Acceptor  \
# 0                  6.0           6.0                  4.0              5.0
# ...

# %%
peptide.columns
# Out:
# Index(['Compounds', 'Molecular Weight', 'Fraction sp3', 'Heavy Atom',
#        'Aromatic Heavy Atom', 'Rotable Bond', 'Hydrogen Bond Donor',
#        'H-Bond Acceptor', 'Molar Refractivity', 'Total polar Surface Area',
#        'Consenus LogP', 'GIT Absorption', 'BBB Permeation', 'P-gp Substrate',
#        'CYPYes A2-', 'CYP2 CYes9-', 'CYP2 C9-', 'CYP2 D6-', 'CYP3 A4-',
#        'Log Kp', 'Lipinski', 'Ghose', 'Veber', 'Egan', 'Mueggage', 'B.Score',
#        'Leadlike', 'Synthetic accessbility', 'Toxicity Class',
#        'Predicted LD 50', 'Estimated ΔG (kcal/mol)', 'FullFitness (kcal/mol)',
#        'Estimated ΔG (kcal/mol).1', 'Full fitness'],
#       dtype='object')

# %%
peptide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Compounds                  45 non-null     object
#  1   Molecular Weight           45 non-null     float64
#  2   Fraction sp3               45 non-null     float64
#  3   Heavy Atom                 45 non-null     float64
#  4   Aromatic Heavy Atom        45 non-null     float64
#  5   Rotable Bond               45 non-null     float64
#  6   Hydrogen Bond Donor        45 non-null     float64
#  7   H-Bond Acceptor            45 non-null     float64
#  8   Molar Refractivity         44 non-null     float64
#  9   Total polar Surface Area   45 non-null     float64
#  10  Consenus LogP              45 non-null     float64
#  11  GIT Absorption             45 non-null     object
#  12  BBB Permeation             45 non-null     object
# ...

# %%
from sklearn.preprocessing import LabelEncoder 
from sklearn.pipeline import Pipeline

# %%
class Multicolumnlabelencoder:
    def __init__(self,columns=None):
        self.columns=columns 
    def fit(self,X,y=None):
        return self
    def transform(self,X):
        output = X.copy()
        if self.columns is not None:
            for col in self.columns:
                output[col] = LabelEncoder().fit_transform(output[col])
        else:
            for colname,col in output.iteritems():
                output[colname] = LabelEncoder().fit_transform(col)
        return output

    def fit_transform(self,X,y=None):
        return self.fit(X,y).transform(X)

# %%
peptidenew=Multicolumnlabelencoder(columns = ['GIT Absorption','BBB Permeation','P-gp Substrate','CYPYes A2-','CYP2 CYes9-','CYP2 C9-','CYP2 D6-','CYP3 A4-','Lipinski','Ghose','Veber','Egan','Mueggage','Leadlike']).fit_transform(peptide)

# %%
peptidenew
# Out:
#                       Compounds  Molecular Weight  Fraction sp3  Heavy Atom  \
# 0              Proline-Tyrosine              2.78          0.43        20.0
# 1            Proline-Tryptophan              3.01          0.38        22.0
# 2         Proline-Phenylalanine              2.62          0.43        19.0
# 3               Proline-Alanine              1.86          0.75        13.0
# 4               Proline-Glycine              1.72          0.71        12.0
# 5                Proline-Valine              2.14          0.80        15.0
# 6              Proline-Cysteine              2.18          0.75        14.0
# 7            Proline-Methionine              2.46          0.80        16.0
# 8               Proline-Leucine              2.28          0.82        16.0
# 9             Proline-Threonine              2.16          0.78        15.0
# 10               Proline-Serine              2.02          0.75        14.0
# ...

# %%
df=peptidenew.iloc[:,1:]
df
# Out:
#     Molecular Weight  Fraction sp3  Heavy Atom  Aromatic Heavy Atom  \
# 0               2.78          0.43        20.0                  6.0
# 1               3.01          0.38        22.0                  9.0
# 2               2.62          0.43        19.0                  6.0
# 3               1.86          0.75        13.0                  0.0
# 4               1.72          0.71        12.0                  0.0
# 5               2.14          0.80        15.0                  0.0
# 6               2.18          0.75        14.0                  0.0
# 7               2.46          0.80        16.0                  0.0
# 8               2.28          0.82        16.0                  0.0
# 9               2.16          0.78        15.0                  0.0
# 10              2.02          0.75        14.0                  0.0
# 11              2.43          0.82        17.0                  0.0
# 12              2.52          0.55        18.0                  5.0
# ...

# %%
len(df)
# Out:
# 46

# %%
df.shape
# Out:
# (46, 32)

# %%
from numpy.linalg import norm

# %%
sd=pd.read_excel('StandardDrugs.xlsx')

# %%
sd.head()
# Out:
#   StandardDrugs   Molecular Weight  Fraction sp3  Heavy Atom  \
# 0      Sorafenib              4.64          0.10          32
# 1     Lenvatinib              4.26          0.19          30
#
#    Aromatic Heavy Atom  Rotable Bond  Hydrogen Bond Donor  H-Bond Acceptor  \
# 0                   18             9                    3                7
# 1                   16             8                    3                5
#
#    Molar Refractivity  Total polar Surface Area  ...  Mueggage  B.Score  \
# 0               0.112                      0.92  ...         1     0.55
# 1               0.112                      1.15  ...         1     0.55
#
#    Leadlike  Synthetic accessbility  Toxicity Class  Predicted LD 50  \
# 0         0                    2.87               4              800
# 1         0                    2.88               5             3000
#
#    Estimated ΔG (kcal/mol)  FullFitness (kcal/mol)  Estimated ΔG (kcal/mol).1  \
# ...

# %%
sdnew=sd.iloc[:,1:]
sd1=[]
sd2=[]
for col in sdnew.columns:
    sd1.append(sdnew.loc[0,col])
    sd2.append(sdnew.loc[1,col])

# %%
sd2
# Out:
# [4.26,
#  0.19,
#  30,
#  16,
#  8,
#  3,
#  5,
#  0.112,
#  1.15,
#  2.81,
#  1,
#  0,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  -6.95,
#  1,
#  1,
#  1,
#  1,
#  1,
#  0.55,
#  0,
#  2.88,
#  5,
#  3000,
#  -8.85,
#  -1851.53,
#  -8.38,
#  -980.15]

# %%
def cosinesimilarity(X,Y):
    similarity_score=np.dot(X,Y)/norm(X)*norm(Y)
    return similarity_score

# %%
dfnew=peptidenew.drop(columns=['Compounds'])
dfnew.shape
a2=[]
a4=[]
compounds=peptidenew['Compounds']
for i in range(len(dfnew)):
    a1=[]
    for col in df.columns:
        a1.append(df.loc[i,col])
    a2.append(cosinesimilarity(a1,sd1))
    a4.append(cosinesimilarity(a1,sd2))

# %%
compounds=peptidenew['Compounds']
drugdata=[compounds,a2,a4]
drugdata
# Out:
# [0                Proline-Tyrosine
#  1              Proline-Tryptophan
#  2           Proline-Phenylalanine
#  3                 Proline-Alanine
#  4                 Proline-Glycine
#  5                  Proline-Valine
#  6                Proline-Cysteine
#  7              Proline-Methionine
#  8                 Proline-Leucine
#  9               Proline-Threonine
#  10                 Proline-Serine
#  11                 Proline-Lysine
#  12              Proline-Histidine
#  13            Proline-Asparginine
#  14               Proline-Arginine
#  15              Proline-Glutamine
#  16           Tryphtophan-Tyrosine
#  17             Tryptophan-Glycine
#  18              Tryptophan-Valine
#  19            Tryptophan-Cysteine
#  20             Tryphtophan-Serine
#  21      Tryphtophan-Phenylalanine
#  22            Tryphtophan-Alanine
#  23          Tryphtophan-Histidine
#  24          Tryphtophan-Threonine
#  25             Tryphtophan-Lysine
#  26            Tryptophan-Arginine
# ...

# %%
similarity1=pd.DataFrame(compounds,columns=['Compounds'])
similarity2=pd.DataFrame(a2,columns=['sd1'])
similarity3=pd.DataFrame(a4,columns=['sd2'])

# %%
similarity1
# Out:
#                       Compounds
# 0              Proline-Tyrosine
# 1            Proline-Tryptophan
# 2         Proline-Phenylalanine
# 3               Proline-Alanine
# 4               Proline-Glycine
# 5                Proline-Valine
# 6              Proline-Cysteine
# 7            Proline-Methionine
# 8               Proline-Leucine
# 9             Proline-Threonine
# 10               Proline-Serine
# 11               Proline-Lysine
# 12            Proline-Histidine
# 13          Proline-Asparginine
# 14             Proline-Arginine
# 15            Proline-Glutamine
# 16         Tryphtophan-Tyrosine
# 17           Tryptophan-Glycine
# 18            Tryptophan-Valine
# 19          Tryptophan-Cysteine
# 20           Tryphtophan-Serine
# 21    Tryphtophan-Phenylalanine
# 22          Tryphtophan-Alanine
# 23        Tryphtophan-Histidine
# 24        Tryphtophan-Threonine
# 25           Tryphtophan-Lysine
# 26          Tryptophan-Arginine
# 27       Tryphtophan-Methionine
# ...

# %%
similarity2
# Out:
#              sd1
# 0   5.614459e+06
# 1   6.060367e+06
# 2   4.344369e+06
# 3   5.267653e+06
# 4   5.269366e+06
# 5   5.265520e+06
# 6   4.356107e+06
# 7   5.556492e+06
# 8   5.265915e+06
# 9   5.257709e+06
# 10  5.257293e+06
# 11  5.274192e+06
# 12  5.266771e+06
# 13  5.467633e+06
# 14  5.928079e+06
# 15           NaN
# 16  4.234588e+06
# 17  6.203625e+06
# 18  6.203898e+06
# 19  6.203944e+06
# 20  6.204794e+06
# 21  6.261167e+06
# 22  6.203999e+06
# 23  5.608584e+06
# 24  6.205039e+06
# 25  6.203975e+06
# 26  6.138752e+06
# 27  4.343947e+06
# 28  6.323217e+06
# 29  6.201904e+06
# 30           NaN
# 31  3.512477e+06
# 32  6.271167e+06
# 33  5.866015e+06
# 34  3.826178e+06
# 35  3.826842e+06
# 36  3.502851e+06
# 37  4.751885e+06
# 38  3.508745e+06
# 39  5.599712e+06
# 40  3.830104e+06
# 41  3.512422e+06
# 42  3.503172e+06
# 43  3.502794e+06
# 44  4.032476e+06
# 45  3.524480e+06

# %%
similarity1['sd1']=similarity2

# %%
similarity1
# Out:
#                       Compounds           sd1
# 0              Proline-Tyrosine  5.614459e+06
# 1            Proline-Tryptophan  6.060367e+06
# 2         Proline-Phenylalanine  4.344369e+06
# 3               Proline-Alanine  5.267653e+06
# 4               Proline-Glycine  5.269366e+06
# 5                Proline-Valine  5.265520e+06
# 6              Proline-Cysteine  4.356107e+06
# 7            Proline-Methionine  5.556492e+06
# 8               Proline-Leucine  5.265915e+06
# 9             Proline-Threonine  5.257709e+06
# 10               Proline-Serine  5.257293e+06
# 11               Proline-Lysine  5.274192e+06
# 12            Proline-Histidine  5.266771e+06
# 13          Proline-Asparginine  5.467633e+06
# 14             Proline-Arginine  5.928079e+06
# 15            Proline-Glutamine           NaN
# 16         Tryphtophan-Tyrosine  4.234588e+06
# 17           Tryptophan-Glycine  6.203625e+06
# 18            Tryptophan-Valine  6.203898e+06
# ...

# %%
similarity1['sd2']=similarity3

# %%
similarity1
# Out:
#                       Compounds           sd1           sd2
# 0              Proline-Tyrosine  5.614459e+06  1.321823e+07
# 1            Proline-Tryptophan  6.060367e+06  8.036734e+06
# 2         Proline-Phenylalanine  4.344369e+06  1.318178e+07
# 3               Proline-Alanine  5.267653e+06  1.336949e+07
# 4               Proline-Glycine  5.269366e+06  1.336899e+07
# 5                Proline-Valine  5.265520e+06  1.336983e+07
# 6              Proline-Cysteine  4.356107e+06  1.318715e+07
# 7            Proline-Methionine  5.556492e+06  1.325515e+07
# 8               Proline-Leucine  5.265915e+06  1.337011e+07
# 9             Proline-Threonine  5.257709e+06  1.337149e+07
# 10               Proline-Serine  5.257293e+06  1.337237e+07
# 11               Proline-Lysine  5.274192e+06  1.336787e+07
# 12            Proline-Histidine  5.266771e+06  1.336999e+07
# 13          Proline-Asparginine  5.467633e+06  1.330404e+07
# 14             Proline-Arginine  5.928079e+06  1.285323e+07
# ...

# %%
sorted_df1 = similarity1.sort_values(by='sd1', ascending=False)

# %%
sorted_df1
# Out:
#                       Compounds           sd1           sd2
# 28   Tryphtophan-Asparatic Acid  6.323217e+06  1.079275e+07
# 32       Phenylalanine-Arginine  6.271167e+06  1.168737e+07
# 21    Tryphtophan-Phenylalanine  6.261167e+06  1.176566e+07
# 24        Tryphtophan-Threonine  6.205039e+06  9.023975e+06
# 20           Tryphtophan-Serine  6.204794e+06  9.021522e+06
# 22          Tryphtophan-Alanine  6.203999e+06  9.019556e+06
# 25           Tryphtophan-Lysine  6.203975e+06  9.018223e+06
# 19          Tryptophan-Cysteine  6.203944e+06  9.021880e+06
# 18            Tryptophan-Valine  6.203898e+06  9.014053e+06
# 17           Tryptophan-Glycine  6.203625e+06  9.012429e+06
# 29        Tryphtophan-Glutamine  6.201904e+06  8.996417e+06
# 26          Tryptophan-Arginine  6.138752e+06  8.526417e+06
# 1            Proline-Tryptophan  6.060367e+06  8.036734e+06
# 14             Proline-Arginine  5.928079e+06  1.285323e+07
# 33  Phenylalanine-Aspartic acid  5.866015e+06  1.295364e+07
# ...

# %%
sorted_df1['Compounds'].head(4)
# Out:
# 28    Tryphtophan-Asparatic Acid
# 32        Phenylalanine-Arginine
# 21     Tryphtophan-Phenylalanine
# 24         Tryphtophan-Threonine
# Name: Compounds, dtype: object

# %%
sorted_df2= similarity1.sort_values(by='sd2', ascending=False)

# %%
sorted_df2
# Out:
#                       Compounds           sd1           sd2
# 10               Proline-Serine  5.257293e+06  1.337237e+07
# 9             Proline-Threonine  5.257709e+06  1.337149e+07
# 8               Proline-Leucine  5.265915e+06  1.337011e+07
# 12            Proline-Histidine  5.266771e+06  1.336999e+07
# 5                Proline-Valine  5.265520e+06  1.336983e+07
# 3               Proline-Alanine  5.267653e+06  1.336949e+07
# 4               Proline-Glycine  5.269366e+06  1.336899e+07
# 11               Proline-Lysine  5.274192e+06  1.336787e+07
# 37         Phenylalanine-Lysine  4.751885e+06  1.334167e+07
# 13          Proline-Asparginine  5.467633e+06  1.330404e+07
# 7            Proline-Methionine  5.556492e+06  1.325515e+07
# 39      Phenylalanine-Histidine  5.599712e+06  1.322812e+07
# 23        Tryphtophan-Histidine  5.608584e+06  1.322235e+07
# 0              Proline-Tyrosine  5.614459e+06  1.321823e+07
# 6              Proline-Cysteine  4.356107e+06  1.318715e+07
# ...

# %%
sorted_df2['Compounds'].head(4)
# Out:
# 10       Proline-Serine
# 9     Proline-Threonine
# 8       Proline-Leucine
# 12    Proline-Histidine
# Name: Compounds, dtype: object

# %%
print("compounds similar to Sorafenib is :",sorted_df1['Compounds'].head(4))
# Out:
# compounds similar to Sorafenib is : 28    Tryphtophan-Asparatic Acid
# 32        Phenylalanine-Arginine
# 21     Tryphtophan-Phenylalanine
# 24         Tryphtophan-Threonine
# Name: Compounds, dtype: object

# %%
print("compounds similar to Lenvatinib is :",sorted_df2['Compounds'].head(4))
# Out:
# compounds similar to Lenvatinib is : 10       Proline-Serine
# 9     Proline-Threonine
# 8       Proline-Leucine
# 12    Proline-Histidine
# Name: Compounds, dtype: object
